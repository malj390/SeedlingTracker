# %% [markdown]
# 1. Open Anaconda promp and write and Enter after each command

# %%
conda activate py38

# %%
jupyter notebook

# %% [markdown]
# To run a notebook you have to press Cell > Run All

# %% [markdown]
# 2. Segmentation of the seedlings

# %%
open Seedling_seg_v3_A

# %% [markdown]
# 3. Cap root tracking (RUN THIS SCRPT STEP BY STEP WITH SHIFT + ENTER)

# %%
open Seedling_seg_v3_A
